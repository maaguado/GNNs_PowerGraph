# %% [markdown]
# # Experimentos - regresión

# %% [markdown]
# ## 1. Carga de datos

# %%
import torch
import torch.nn.functional as F
import pandas as pd
import seaborn as sns
import networkx as nx
sns.set_palette("coolwarm_r")
import matplotlib.pyplot as plt
import numpy as np

from torch_geometric.data import Data, Dataset
from torch_geometric.nn import GCNConv

# %%
import os, sys

path = os.getcwd()

sys.path.insert(1, "/".join(path.split("/")[0:-2]))

# %%
from torch_geometric_temporal.nn.recurrent import GCLSTM

from torch_geometric_temporal.dataset import EnglandCovidDatasetLoader
from torch_geometric_temporal.signal import temporal_signal_split
from utils.dynamic_graph_temporal_signal import DynamicGraphTemporalSignalLen
from utils import powergrid

# %%
def format_plot(ax):
    sns.despine(ax=ax, top=True, right=True, left=False, bottom=False)
    ax.spines['left'].set_color('dimgrey')
    ax.spines['bottom'].set_color('dimgrey')

    ax.xaxis.label.set_color('dimgrey')
    ax.tick_params(axis='both', colors='dimgrey', size=12, pad=1)

# %%
folder_path = "/home/TFM/code_dataset2/datos/Natural Oscillation"

# %%
loader = powergrid.PowerGridDatasetLoader(folder_path, problem="regression")
_,_,_=loader.process()
# Out:
# Processing:  row_214
# Node:  0  not included, including...
# Node:  1  not included, including...
# Node:  2  not included, including...
# Node:  3  not included, including...
# Node:  4  not included, including...
# Node:  5  not included, including...
# Node:  6  not included, including...
# Node:  7  not included, including...
# Node:  8  not included, including...
# Node:  9  not included, including...
# Node:  10  not included, including...
# Node:  11  not included, including...
# Node:  12  not included, including...
# Node:  13  not included, including...
# Node:  14  not included, including...
# Node:  15  not included, including...
# Node:  16  not included, including...
# Node:  17  not included, including...
# Node:  18  not included, including...
# Node:  19  not included, including...
# Node:  20  not included, including...
# Node:  21  not included, including...
# Node:  22  not included, including...
# Processing:  row_32
# Processing:  row_57
# Processing:  row_110
# Processing:  row_248
# Processing:  row_119
# Processing:  row_171
# Processing:  row_305
# Processing:  row_199
# Processing:  row_203
# Processing:  row_469
# Processing:  row_77
# Processing:  row_50
# Processing:  row_303
# Processing:  row_153
# Processing:  row_545
# Processing:  row_75
# Processing:  row_100
# Processing:  row_324
# Processing:  row_271
# Processing:  row_280
# Processing:  row_106
# Processing:  row_195
# Processing:  row_440
# Processing:  row_419
# Processing:  row_317
# Processing:  row_135
# Processing:  row_323
# Processing:  row_22
# Processing:  row_265
# Processing:  row_70
# Processing:  row_21
# Processing:  row_438
# Processing:  row_270
# Processing:  row_463
# Processing:  row_344
# Processing:  row_316
# Processing:  row_538
# Processing:  row_382
# Processing:  row_501
# Processing:  row_94
# Processing:  row_266
# Processing:  row_503
# Processing:  row_365
# Processing:  row_39
# Processing:  row_267
# Processing:  row_213
# Processing:  row_66
# Processing:  row_118
# Processing:  row_387
# Processing:  row_386
# Processing:  row_441
# Processing:  row_20
# Processing:  row_186
# Processing:  row_78
# Processing:  row_9
# Processing:  row_69
# Processing:  row_496
# Processing:  row_408
# Processing:  row_450
# Processing:  row_79
# Processing:  row_357
# Processing:  row_180
# Processing:  row_384
# Processing:  row_421
# Processing:  row_529
# Processing:  row_479
# Processing:  row_252
# Processing:  row_288
# Processing:  row_278
# Processing:  row_535
# Processing:  row_461
# Processing:  row_465
# Processing:  row_89
# Processing:  row_508
# Processing:  row_485
# Processing:  row_207
# Processing:  row_85
# Processing:  row_164
# Processing:  row_376
# Processing:  row_414
# Processing:  row_295
# Processing:  row_12
# Processing:  row_250
# Processing:  row_3
# Processing:  row_175
# Processing:  row_548
# Processing:  row_292
# Processing:  row_431
# Processing:  row_351
# Processing:  row_510
# Processing:  row_400
# Processing:  row_458
# Processing:  row_212
# Processing:  row_224
# Processing:  row_109
# Processing:  row_336
# Processing:  row_141
# Processing:  row_412
# Processing:  row_93
# Processing:  row_374
# Processing:  row_225
# Processing:  row_356
# Processing:  row_24
# Processing:  row_462
# Processing:  row_333
# Processing:  row_328
# Skipping  row_328
# Processing:  row_276
# Processing:  row_162
# Processing:  row_37
# Processing:  row_230
# Processing:  row_282
# Processing:  row_392
# Processing:  row_335
# Processing:  row_104
# Processing:  row_47
# Processing:  row_415
# Processing:  row_167
# Processing:  row_245
# Processing:  row_127
# Processing:  row_425
# Processing:  row_314
# Processing:  row_238
# Processing:  row_221
# Processing:  row_92
# Processing:  row_260
# Processing:  row_55
# Processing:  row_223
# Processing:  row_306
# Processing:  row_129
# Processing:  row_383
# Processing:  row_320
# Processing:  row_437
# Processing:  row_347
# Processing:  row_198
# Processing:  row_308
# Processing:  row_116
# Processing:  row_371
# Processing:  row_235
# Processing:  row_168
# Processing:  row_364
# Processing:  row_68
# Processing:  row_519
# Processing:  row_130
# Processing:  row_142
# Processing:  row_178
# Processing:  row_403
# Processing:  row_368
# Processing:  row_291
# Processing:  row_242
# Processing:  row_181
# Processing:  row_452
# Processing:  row_217
# Processing:  row_249
# Processing:  row_111
# Processing:  row_393
# Processing:  row_334
# Processing:  row_411
# Processing:  row_435
# Processing:  row_35
# Processing:  row_381
# Processing:  row_10
# Processing:  row_134
# Processing:  row_218
# Processing:  row_301
# Processing:  row_102
# Processing:  row_124
# Processing:  row_115
# Processing:  row_349
# Processing:  row_184
# Processing:  row_416
# Processing:  row_148
# Processing:  row_239
# Processing:  row_237
# Processing:  row_125
# Processing:  row_136
# Processing:  row_318
# Processing:  row_426
# Processing:  row_31
# Processing:  row_360
# Processing:  row_263
# Processing:  row_122
# Processing:  row_418
# Processing:  row_259
# Processing:  row_138
# Processing:  row_489
# Processing:  row_257
# Processing:  row_352
# Processing:  row_315
# Processing:  row_345
# Processing:  row_512
# Processing:  row_52
# Processing:  row_446
# Processing:  row_310
# Processing:  row_274
# Processing:  row_73
# Processing:  row_484
# Processing:  row_191
# Processing:  row_516
# Processing:  row_14
# Processing:  row_272
# Processing:  row_48
# Processing:  row_358
# Processing:  row_194
# Processing:  row_256
# Processing:  row_354
# Processing:  row_490
# Processing:  row_311
# Processing:  row_200
# Processing:  row_456
# Processing:  row_513
# Processing:  row_149
# Processing:  row_294
# Processing:  row_219
# Processing:  row_528
# Processing:  row_86
# Processing:  row_498
# Processing:  row_99
# Processing:  row_123
# Processing:  row_550
# Processing:  row_375
# Processing:  row_327
# Processing:  row_524
# Processing:  row_258
# Processing:  row_511
# Processing:  row_137
# Processing:  row_179
# Processing:  row_478
# Processing:  row_422
# Processing:  row_296
# Processing:  row_74
# Processing:  row_59
# Processing:  row_26
# Processing:  row_208
# Processing:  row_193
# Processing:  row_72
# Processing:  row_268
# Processing:  row_16
# Processing:  row_243
# Processing:  row_67
# Processing:  row_56
# Processing:  row_220
# Processing:  row_233
# Processing:  row_240
# Processing:  row_190
# Processing:  row_273
# Processing:  row_132
# Processing:  row_434
# Processing:  row_255
# Processing:  row_447
# Processing:  row_457
# Processing:  row_312
# Processing:  row_517
# Processing:  row_101
# Processing:  row_363
# Processing:  row_532
# Processing:  row_369
# Processing:  row_81
# Processing:  row_428
# Processing:  row_526
# Processing:  row_472
# Processing:  row_229
# Processing:  row_304
# Processing:  row_332
# Processing:  row_49
# Processing:  row_189
# Processing:  row_326
# Processing:  row_424
# Processing:  row_228
# Processing:  row_330
# Processing:  row_331
# Processing:  row_96
# Processing:  row_204
# Processing:  row_491
# Processing:  row_38
# Processing:  row_146
# Processing:  row_541
# Processing:  row_18
# Processing:  row_113
# Processing:  row_36
# Processing:  row_88
# Processing:  row_211
# Processing:  row_91
# Processing:  row_406
# Processing:  row_432
# Processing:  row_539
# Processing:  row_359
# Processing:  row_140
# Processing:  row_15
# Processing:  row_530
# Processing:  row_11
# Processing:  row_170
# Processing:  row_388
# Processing:  row_322
# Processing:  row_547
# Processing:  row_467
# Processing:  row_286
# Processing:  row_474
# Processing:  row_279
# Processing:  row_42
# Processing:  row_246
# Processing:  row_251
# Processing:  row_487
# Processing:  row_377
# Processing:  row_395
# Processing:  row_29
# Processing:  row_261
# Processing:  row_427
# Processing:  row_348
# Processing:  row_290
# Processing:  row_128
# Processing:  row_232
# Processing:  row_454
# Processing:  row_494
# Processing:  row_201
# Processing:  row_231
# Processing:  row_399
# Processing:  row_103
# Processing:  row_396
# Processing:  row_187
# Processing:  row_518
# Processing:  row_188
# Processing:  row_58
# Processing:  row_297
# Processing:  row_300
# Processing:  row_343
# Processing:  row_397
# Processing:  row_429
# Processing:  row_34
# Processing:  row_241
# Processing:  row_61
# Processing:  row_401
# Processing:  row_389
# Processing:  row_483
# Processing:  row_7
# Processing:  row_536
# Processing:  row_236
# Processing:  row_509
# Processing:  row_402
# Processing:  row_355
# Processing:  row_133
# Processing:  row_183
# Processing:  row_23
# Processing:  row_470
# Processing:  row_439
# Processing:  row_455
# Processing:  row_244
# Processing:  row_284
# Processing:  row_287
# Processing:  row_366
# Processing:  row_500
# Processing:  row_13
# Processing:  row_234
# Processing:  row_497
# Processing:  row_307
# Processing:  row_475
# Processing:  row_156
# Processing:  row_155
# Processing:  row_480
# Processing:  row_338
# Processing:  row_495
# Processing:  row_64
# Processing:  row_262
# Processing:  row_46
# Processing:  row_147
# Processing:  row_84
# Processing:  row_60
# Processing:  row_339
# Processing:  row_254
# Processing:  row_362
# Processing:  row_90
# Processing:  row_520
# Processing:  row_337
# Processing:  row_493
# Processing:  row_533
# Processing:  row_459
# Processing:  row_82
# Processing:  row_145
# Processing:  row_523
# Processing:  row_543
# Processing:  row_540
# Processing:  row_63
# Processing:  row_158
# Processing:  row_507
# Processing:  row_112
# Processing:  row_83
# Processing:  row_283
# Processing:  row_342
# Processing:  row_169
# Processing:  row_302
# Processing:  row_157
# Processing:  row_504
# Processing:  row_527
# Processing:  row_5
# Processing:  row_205
# Processing:  row_361
# Processing:  row_139
# Processing:  row_460
# Processing:  row_65
# Processing:  row_202
# Processing:  row_506
# Processing:  row_6
# Processing:  row_379
# Processing:  row_150
# Processing:  row_398
# Processing:  row_522
# Processing:  row_448
# Processing:  row_160
# Processing:  row_196
# Processing:  row_537
# Processing:  row_105
# Processing:  row_385
# Processing:  row_442
# Processing:  row_173
# Processing:  row_444
# Processing:  row_391
# Processing:  row_488
# Processing:  row_468
# Processing:  row_390
# Processing:  row_226
# Processing:  row_44
# Processing:  row_182
# Processing:  row_451
# Processing:  row_471
# Processing:  row_19
# Processing:  row_1
# Processing:  row_299
# Processing:  row_108
# Processing:  row_269
# Processing:  row_152
# Processing:  row_117
# Processing:  row_481
# Processing:  row_544
# Processing:  row_206
# Processing:  row_43
# Processing:  row_443
# Processing:  row_120
# Processing:  row_464
# Processing:  row_313
# Processing:  row_289
# Processing:  row_154
# Processing:  row_76
# Processing:  row_321
# Processing:  row_192
# Processing:  row_404
# Processing:  row_521
# Processing:  row_174
# Processing:  row_17
# Processing:  row_107
# Processing:  row_394
# Processing:  row_409
# Processing:  row_285
# Processing:  row_373
# Processing:  row_534
# Processing:  row_215
# Processing:  row_370
# Processing:  row_417
# Processing:  row_253
# Processing:  row_329
# Processing:  row_542
# Processing:  row_53
# Processing:  row_325
# Processing:  row_264
# Processing:  row_515
# Processing:  row_172
# Processing:  row_514
# Processing:  row_275
# Processing:  row_8
# Processing:  row_346
# Processing:  row_4
# Processing:  row_405
# Processing:  row_51
# Processing:  row_413
# Processing:  row_80
# Processing:  row_499
# Processing:  row_177
# Processing:  row_209
# Processing:  row_71
# Processing:  row_420
# Processing:  row_247
# Processing:  row_185
# Processing:  row_126
# Processing:  row_54
# Processing:  row_473
# Processing:  row_453
# Processing:  row_216
# Processing:  row_114
# Processing:  row_62
# Processing:  row_33
# Processing:  row_433
# Processing:  row_143
# Processing:  row_28
# Processing:  row_380
# Processing:  row_445
# Processing:  row_163
# Processing:  row_482
# Processing:  row_309
# Processing:  row_277
# Processing:  row_505
# Processing:  row_372
# Processing:  row_30
# Processing:  row_144
# Processing:  row_502
# Processing:  row_210
# Processing:  row_166
# Processing:  row_227
# Processing:  row_476
# Processing:  row_161
# Processing:  row_410
# Processing:  row_423
# Processing:  row_350
# Processing:  row_25
# Processing:  row_298
# Processing:  row_222
# Processing:  row_165
# Processing:  row_378
# Processing:  row_131
# Processing:  row_159
# Processing:  row_549
# Processing:  row_340
# Processing:  row_176
# Processing:  row_546
# Processing:  row_98
# Processing:  row_486
# Processing:  row_531
# Processing:  row_293
# Processing:  row_407
# Processing:  row_40
# Processing:  row_45
# Processing:  row_353
# Processing:  row_367
# Processing:  row_319
# Processing:  row_2
# Processing:  row_27
# Processing:  row_430
# Processing:  row_281
# Processing:  row_121
# Processing:  row_466
# Processing:  row_492
# Processing:  row_151
# Processing:  row_449
# Processing:  row_95
# Processing:  row_436
# Processing:  row_525
# Processing:  row_341
# Processing:  row_477
# Processing:  row_41
# Processing:  row_87
# Processing:  row_97
# Processing:  row_197

# %%
info_nodos = loader.reconstruir_voltages(1)


n_plots = 23
n_cols = 2
n_rows = (n_plots + 1) // 2  # División redondeada hacia arriba

fig, axs = plt.subplots(n_rows, n_cols, figsize=(10, 20),dpi=200)
# Trazar los gráficos
for i in range(n_plots):
    row = i % n_rows  # Calculamos el índice de la fila
    col = i // n_rows  # Calculamos el índice de la columna
    ax = axs[row, col] if n_plots > 1 else axs
    
    ax = axs[row, col] if n_plots > 1 else axs
    
    sns.lineplot(y=info_nodos[i],x=range(len(info_nodos[i])), ax=ax, label='Real', legend=False)
        
    ax.set_title(f'Nodo {i+1}')
    format_plot(ax)
    # Añadir leyenda solo al último plot
    if i == n_plots - 1:
        ax.legend(loc='upper left')

if n_plots % n_cols != 0:
    fig.delaxes(axs.flatten()[-1])
# Ajustes finales
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Experimentos
#
#
# ### Funciones auxiliares

# %%
from utils import pygt_loader

try:
    from tqdm import tqdm
except ImportError:
    def tqdm(iterable):
        return iterable
import os
import torch
import torch.nn.functional as F
from torch_geometric_temporal.nn.recurrent import AGCRN
from sklearn.metrics import r2_score

from torch.optim.lr_scheduler import ReduceLROnPlateau


from utils.trainer import TrainerModel
from utils import trainer
dtype = torch.float
device = torch.device("cpu")

# %%
def reconstruir_predictions(predictions,real, n_target, situacion, n_div, n_nodes=23):
    
    temp = np.array(predictions).reshape(-1, n_nodes, n_target)
    temp2 =np.array(real).reshape(-1, n_nodes, n_target)
    if n_div != None:
        id_situacion = situacion*n_div 
        return n_div, np.concatenate([np.array(temp[id_situacion+i]) for i in range(n_div)], axis=1), np.concatenate([np.array(temp2[id_situacion+i]) for i in range(n_div)], axis=1)
    m = temp.shape[0]
    return m, np.concatenate([np.array(temp[situacion+i]) for i in range(m)], axis=1), np.concatenate([np.array(temp2[situacion+i]) for i in range(m)], axis=1)

# %%
def plot_training_and_eval_losses(train_losses, eval_losses, num_epochs, format_plot):
    epochs = range(1, num_epochs + 1)


    plt.figure(figsize=(12, 5), dpi=200)
    ax = plt.gca()

    sns.lineplot(x=epochs, y=train_losses, label='Training Loss')
    sns.lineplot(x=epochs, y=eval_losses, label='Evaluation Loss', color="royalblue")
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.set_title('Loss by Epoch')
    ax.legend()
    format_plot(ax) 
    plt.tight_layout()
    plt.show()

# %%
def plot_predictions(predictions, real, n_target, n_situation, n_div=None):
    
    m, preds, y_true = reconstruir_predictions(predictions,real, n_target, n_situation, n_div=n_div)
    n_plots = 23
    n_cols = 2
    n_rows = (n_plots + 1) // 2  # División redondeada hacia arriba

    fig, axs = plt.subplots(n_rows, n_cols, figsize=(10, 20),dpi=200)
    # Trazar los gráficos
    for i in range(n_plots):
        row = i % n_rows  # Calculamos el índice de la fila
        col = i // n_rows  # Calculamos el índice de la columna
        ax = axs[row, col] if n_plots > 1 else axs
        
        ax = axs[row, col] if n_plots > 1 else axs
        
        sns.lineplot(y=y_true[i],x=range(n_target*m), ax=ax, label='Real', legend=False, color="royalblue")
        

        sns.lineplot(y=preds[i],x=range(n_target*m),ax=ax, label='Predicciones', legend=False)
        
        ax.set_title(f'Nodo {i+1}')
        format_plot(ax)
        # Añadir leyenda solo al último plot
        if i == n_plots - 1:
            ax.legend(loc='upper left')

    if n_plots % n_cols != 0:
        fig.delaxes(axs.flatten()[-1])
    # Ajustes finales
    plt.tight_layout()
    plt.show()

# %%
class RecurrentGCN(torch.nn.Module):
    def __init__(self, n_features, n_nodes, embedding_dim, name, n_target):
        self.name  =name
        self.n_nodes = n_nodes
        self.n_target = n_target
        self.embedding_dim =embedding_dim
        self.n_features = n_features
        super(RecurrentGCN, self).__init__()

        self.recurrent = AGCRN(number_of_nodes = n_nodes,
                              in_channels = n_features,
                              out_channels = n_nodes,
                              K = 2,
                              embedding_dimensions = embedding_dim)
        self.linear = torch.nn.Linear(n_nodes,n_target)



    def forward(self, x, e, h):
        h_0 = self.recurrent(x, e, h)
        y = F.relu(h_0)
        y = self.linear(y)
        return y, h_0

# %%
def eval(model, dataloader, e, h):
    model.eval()
    e_loss_batch, r2_loss_batch = [], []
    
    for batch in dataloader['val']:
        batch = batch.to(device)
        x = batch.x.view(len(batch), model.n_nodes, model.n_features)
        y_hat, h = model(x, e, h)
        loss = F.mse_loss(y_hat.view(-1, model.n_target), batch.y).item()
        r2_loss_batch.append(r2_score(batch.y.cpu(), y_hat.view(-1, model.n_target).cpu()))
        e_loss_batch.append(loss)
    return e_loss_batch, r2_loss_batch



def train(model,dataloader, num_early_stop, num_epochs, lr ):

    print("\n==================== TRAIN INFO ===================\n")

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    model.to(device)
    lr_schedule = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, min_lr=0.001)
    early_stop_counter = 0
    best_eval_r2score = -100.0
    best_eval_loss = float('inf')
    losses = []
    eval_losses, r2scores = [], []
    is_best = False

    e = torch.empty(model.n_nodes, model.embedding_dim)
    torch.nn.init.xavier_uniform_(e)
    i = 0

    for epoch in range(num_epochs):
        h = None
        losses_batch = []
        model.train()
        
        for batch in dataloader['train']:
            x = batch.x.view(len(batch), model.n_nodes, model.n_features)
            y_hat, h = model(x, e, h)
            loss = F.mse_loss(y_hat.view(-1, model.n_target), batch.y)
            loss.backward(retain_graph=False)
            loss = loss.detach()
            h = h.detach()
            losses_batch.append(loss.item())
            optimizer.step()
            optimizer.zero_grad()
            i += 1
            
        train_loss = torch.FloatTensor(losses_batch).mean().item()
        losses.append(losses_batch)
    
        with torch.no_grad():
            e_loss_batch, r2_loss_batch = eval(model, dataloader, e, h)
            eval_loss = torch.FloatTensor(e_loss_batch).mean().item()
            eval_r2score = torch.FloatTensor(r2_loss_batch).mean().item()
            eval_losses.append(e_loss_batch)
            r2scores.append(r2_loss_batch)
        
        print(f"Epoch {epoch + 1}/{num_epochs} | "
            f"Train Loss: {train_loss:.4f} | "
            f"Eval Loss: {eval_loss:.4f} | "
            f"Eval R2: {eval_r2score:.4f} | "
            f"LR: {optimizer.param_groups[0]['lr']:.6f}")
        
        if num_early_stop > 0:
            if eval_loss <= best_eval_loss:
                best_eval_loss = eval_loss
                early_stop_counter = 0
            else:
                early_stop_counter += 1
            if epoch > num_epochs / 2 and early_stop_counter > num_early_stop:
                print("Early stopping triggered.")
                break
            
        if lr_schedule:
            lr_schedule.step(eval_loss)

        if best_eval_r2score < eval_r2score:
            is_best = True
            best_eval_r2score = eval_r2score
        recording = {"epoch": epoch, "is_best": str(is_best)}
    return losses, eval_losses, r2scores, e, h
    print("\nTraining completed.")


def test(model, dataloader, e, h):
    
    print("\n==================== TEST INFO ===================\n")
    
    model.eval()
    predictions = []
    real =[]
    losses_tst, r2score_tst = [], []

    for batch in dataloader['test']:
        batch = batch.to(device)
        x = batch.x.view(len(batch), model.n_nodes, model.n_features)
        y_hat,h = model(x, e, h)
        loss = F.mse_loss(y_hat.view(-1, model.n_target), batch.y).item()
        preds = y_hat.view(len(batch), model.n_nodes, model.n_target)
        real.append(batch.y.view(len(batch), model.n_nodes, model.n_target).cpu())
        predictions.append(preds.cpu().detach().numpy())
        r2score_tst.append(r2_score(batch.y.detach().cpu(), y_hat.view(-1, model.n_target).detach().cpu()))
        losses_tst.append(loss)
    test_loss = torch.tensor(r2score_tst).mean().item()
    test_r2score = np.mean(losses_tst)

    print(f"Test_loss:{test_loss:.4f}, Test_r2:{test_r2score:.4f}")
    return r2score_tst, losses_tst, predictions, real

# %% [markdown]
# ### Recurrentes
#
# (En proceso)

# %%
limit = 350
dataset,situations_each = loader.get_dataset( target= 20, intro=300, step=20, limit=limit, one_ts_per_situation=False)
n_div = int(len(dataset) // limit)
print(n_div)
# Out:
# Number of situations:  549
# Number of timestamps:  800
# Number of situations of the selected type:  549
# 24

# %% [markdown]
# #### AGCRN
#
# https://arxiv.org/abs/2007.02842

# %%
n_nodes =dataset.features[0].shape[0]
n_target = dataset.targets[0].shape[1]
n_features = dataset[0].x.shape[1]
embedding_dim =5
print("INFO:")
print(f"Number of nodes: {n_nodes}")
print(f"Number of features: {n_features}")
print(f"Number of target: {n_target}")
print(f"Embedding dimension: {embedding_dim}")
# Out:
# INFO:
# Number of nodes: 23
# Number of features: 300
# Number of target: 20
# Embedding dimension: 5

# %%
dataloader_params2 = {
            "batch_size": 5,
            "data_split_ratio": [0.7, 0.15, 0.15],
            "seed": 42,
            "keep_same": True
        }
dataloader = trainer.train_test_val_split(dataset, **dataloader_params2)

num_early_stop = 0
num_epochs = 30
lr = 0.01
model = RecurrentGCN(n_features=n_features, n_nodes=n_nodes, embedding_dim=embedding_dim, n_target=n_target, name="RecurrentGCNInicial")
losses,eval_losses, r2scores, e, h = train(model, dataloader, num_early_stop, num_epochs, lr)
plot_training_and_eval_losses(np.array(losses).mean(axis=1), np.array(eval_losses).mean(axis=1), num_epochs, format_plot)
losses_tst, r2score_tst, predictions, real = test(model, dataloader, e, h)
# Out:
# ==================== DATASET INFO ===================
#
# Train dataset: 6720
# Validation dataset: 840
# Test dataset: 840
#
# ==================== DATALOADER INFO ===================
#
# DataLoader for train set:
# Number of batches: 1344
# DataLoader for val set:
# Number of batches: 168
# DataLoader for test set:
# Number of batches: 168
#
# ==================== TRAIN INFO ===================
#
# Epoch 1/30 | Train Loss: 0.1497 | Eval Loss: 0.1215 | Eval R2: -19.8052 | LR: 0.010000
# Epoch 2/30 | Train Loss: 0.1094 | Eval Loss: 0.1156 | Eval R2: -23.3567 | LR: 0.010000
# Epoch 3/30 | Train Loss: 0.0979 | Eval Loss: 0.1284 | Eval R2: -31.2118 | LR: 0.010000
# Epoch 4/30 | Train Loss: 0.0978 | Eval Loss: 0.1023 | Eval R2: -21.9464 | LR: 0.010000
# Epoch 5/30 | Train Loss: 0.0774 | Eval Loss: 0.0807 | Eval R2: -13.4171 | LR: 0.010000
# Epoch 6/30 | Train Loss: 0.0741 | Eval Loss: 0.0960 | Eval R2: -22.9167 | LR: 0.010000
# Epoch 7/30 | Train Loss: 0.0756 | Eval Loss: 0.0962 | Eval R2: -24.0557 | LR: 0.010000
# Epoch 8/30 | Train Loss: 0.0676 | Eval Loss: 0.0706 | Eval R2: -8.8597 | LR: 0.010000
# Epoch 9/30 | Train Loss: 0.0649 | Eval Loss: 0.0692 | Eval R2: -11.3575 | LR: 0.010000
# Epoch 10/30 | Train Loss: 0.0653 | Eval Loss: 0.0878 | Eval R2: -21.4287 | LR: 0.010000
# Epoch 11/30 | Train Loss: 0.0601 | Eval Loss: 0.0720 | Eval R2: -9.6760 | LR: 0.010000
# Epoch 12/30 | Train Loss: 0.0575 | Eval Loss: 0.0636 | Eval R2: -9.3608 | LR: 0.010000
# Epoch 13/30 | Train Loss: 0.0565 | Eval Loss: 0.0698 | Eval R2: -13.6222 | LR: 0.010000
# Epoch 14/30 | Train Loss: 0.0554 | Eval Loss: 0.0547 | Eval R2: -5.4233 | LR: 0.010000
# Epoch 15/30 | Train Loss: 0.0538 | Eval Loss: 0.0693 | Eval R2: -9.9551 | LR: 0.010000
# Epoch 16/30 | Train Loss: 0.0542 | Eval Loss: 0.0838 | Eval R2: -15.8704 | LR: 0.010000
# Epoch 17/30 | Train Loss: 0.0536 | Eval Loss: 0.0589 | Eval R2: -6.3215 | LR: 0.010000
# Epoch 18/30 | Train Loss: 0.0414 | Eval Loss: 0.0463 | Eval R2: -3.7203 | LR: 0.001000
# Epoch 19/30 | Train Loss: 0.0372 | Eval Loss: 0.0445 | Eval R2: -3.3527 | LR: 0.001000
# Epoch 20/30 | Train Loss: 0.0363 | Eval Loss: 0.0439 | Eval R2: -3.6195 | LR: 0.001000
# Epoch 21/30 | Train Loss: 0.0357 | Eval Loss: 0.0433 | Eval R2: -3.3198 | LR: 0.001000
# Epoch 22/30 | Train Loss: 0.0353 | Eval Loss: 0.0429 | Eval R2: -3.2130 | LR: 0.001000
# Epoch 23/30 | Train Loss: 0.0345 | Eval Loss: 0.0427 | Eval R2: -3.7739 | LR: 0.001000
# Epoch 24/30 | Train Loss: 0.0342 | Eval Loss: 0.0427 | Eval R2: -3.5481 | LR: 0.001000
# Epoch 25/30 | Train Loss: 0.0340 | Eval Loss: 0.0418 | Eval R2: -3.5003 | LR: 0.001000
# Epoch 26/30 | Train Loss: 0.0333 | Eval Loss: 0.0410 | Eval R2: -3.0668 | LR: 0.001000
# Epoch 27/30 | Train Loss: 0.0329 | Eval Loss: 0.0408 | Eval R2: -3.2700 | LR: 0.001000
# Epoch 28/30 | Train Loss: 0.0328 | Eval Loss: 0.0414 | Eval R2: -3.5824 | LR: 0.001000
# Epoch 29/30 | Train Loss: 0.0325 | Eval Loss: 0.0409 | Eval R2: -3.3751 | LR: 0.001000
# Epoch 30/30 | Train Loss: 0.0326 | Eval Loss: 0.0407 | Eval R2: -3.3073 | LR: 0.001000
# ==================== TEST INFO ===================
#
# Test_loss:-2.7460, Test_r2:0.0342

# %%
plot_predictions(predictions, real, n_target, 0, n_div = n_div)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_predictions(predictions, real, n_target, 0, n_div = n_div)
#
# NameError: name 'plot_predictions' is not defined

# %% [markdown]
# #### EvolveGCN
#
# https://arxiv.org/abs/1902.10191

# %% [markdown]
# #### A3TGCN
#
# https://arxiv.org/abs/2006.11583

# %%
from utils import pygt_loader

try:
    from tqdm import tqdm
except ImportError:
    def tqdm(iterable):
        return iterable
import os
import torch
import torch.nn.functional as F
from torch_geometric_temporal.nn.recurrent import AGCRN, TGCN, A3TGCN2
from sklearn.metrics import r2_score
from torch.optim.lr_scheduler import ReduceLROnPlateau



from utils.trainer import TrainerModel
from utils import trainer

# %%
dtype = torch.float
device = torch.device("cpu")

# %%
from utils import attention_temporal_gcn
from utils import temporal_gcn 
import importlib


importlib.reload(temporal_gcn)

# Reload the module to reflect the changes
importlib.reload(attention_temporal_gcn)
# Out:
# <module 'utils.attention_temporal_gcn' from '/home/TFM/code_dataset2/utils/attention_temporal_gcn.py'>

# %%
n_nodes =dataset.features[0].shape[0]
n_target = dataset.targets[0].shape[1]
n_features_edges = dataset.edge_indices[0].shape[2]
n_time_periods_intro = dataset[0].x.shape[1]
n_edges = dataset.edge_indices[0].shape[1]
embedding_dim =32

class RecurrentGCN(torch.nn.Module):
    def __init__(self, node_features, batch_size, name, node_dim):
        self.name  =name
        self.batch_size = batch_size
        self.node_dim = node_dim
        super(RecurrentGCN, self).__init__()

        self.recurrent = attention_temporal_gcn.A3TGCN2(periods =node_features,
                              in_channels = 1,
                              out_channels = n_nodes,
                              batch_size = batch_size, node_dim = node_dim)
        self.linear = torch.nn.Linear(n_nodes,n_target)



    def forward(self, x, edge_index, edge_weight=None):
        h = self.recurrent(x, edge_index, edge_weight)
        h = F.relu(h)
        h = self.linear(h)
        return h

# %%
bs=20
model = RecurrentGCN(node_features = n_time_periods_intro, name = "RecurrentGCNInicial", batch_size=bs, node_dim = 1)

# %%
dataloader_params2 = {
            "batch_size": bs,
            "data_split_ratio": [0.8, 0.1, 0.1],
            "seed": 42
        }
dataloader = trainer.train_test_val_split(dataset, **dataloader_params2)
# Out:
# Number of series in each dataset:
# Train dataset: 645
# Validation dataset: 75
# Test dataset: 80
#
# DataLoader information:
# DataLoader for train set:
# Number of batches: 32
# DataLoader for val set:
# Number of batches: 3
# DataLoader for test set:
# Number of batches: 4

# %%
num_early_stop = 0
num_epochs = 30
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
model.to(device)
lr_schedule = ReduceLROnPlateau(
                optimizer, mode='min', factor=0.1, patience=2, min_lr=0.001)
early_stop_counter = 0
best_eval_r2score = -100.0
best_eval_loss = 0.0
losses = []


#e = torch.empty(n_nodes, embedding_dim)
#torch.nn.init.xavier_uniform_(e)
i =0
for epoch in range(num_epochs):
    model.train()
    h = None
    for batch in dataloader['train']:
        batch = batch.to(device)  
        edge_index = batch.edge_index.view(n_time_periods_intro, n_edges,len(batch),2).permute(0, 2, 3, 1)
        edge_weight = batch.edge_attr.view(n_time_periods_intro, len(batch), n_edges, n_features_edges  )[:,:,:,0]
        x = batch.x.view(len(batch),  n_nodes,n_time_periods_intro )
        y_hat = model(x, edge_index, edge_weight).view(len(batch)* n_nodes, n_target)
        y_real = batch.y
        loss = F.mse_loss(y_hat, y_real)
        loss.backward(retain_graph=True)
        losses.append(loss.item())
        optimizer.zero_grad()
        optimizer.step()
        i+=1
        #print("batch: ", i)
    train_loss =torch.FloatTensor(losses).mean().item()
    with torch.no_grad():
        model.eval()
        losses, r2scores = [], []
        for batch in dataloader['val']:
            batch = batch.to(device)  
            edge_index = batch.edge_index.view(n_time_periods_intro, n_edges,len(batch),2).permute(0, 2, 3, 1)
            edge_weight = batch.edge_attr.view(n_time_periods_intro, len(batch), n_edges, n_features_edges  )[:,:,:,0]
            x = batch.x.view(len(batch),  n_nodes,n_time_periods_intro )
            y_hat = model(x, edge_index, edge_weight).view(len(batch)* n_nodes, n_target)
            y_real = batch.y
            loss = F.mse_loss(y_hat, y_real).item()
            r2scores.append(r2_score(y_real.cpu(), y_hat.cpu()))
            losses.append(loss)
        eval_loss = torch.tensor(losses).mean().item()
        eval_r2score = np.mean(r2scores)
        
    print(f"Epoch:{epoch}, Training_loss:{train_loss:.4f}, Eval_loss:{eval_loss:.4f}, Eval_r2:{eval_r2score:.4f}, lr:{optimizer.param_groups[0]['lr']}")
    if num_early_stop > 0:
        if eval_loss <= best_eval_loss:
            best_eval_loss = eval_loss
            early_stop_counter = 0
        else:
            early_stop_counter += 1
        if epoch > num_epochs / 2 and early_stop_counter > num_early_stop:
            break
        
    if lr_schedule:
        lr_schedule.step(eval_loss)

    if best_eval_r2score < eval_r2score:
        is_best = True
        best_eval_r2score = eval_r2score
    recording = {"epoch": epoch, "is_best": str(is_best)}
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[15], line 45
#
#      43     y_real = batch.y
#
#      44     loss = F.mse_loss(y_hat, y_real).item()
#
# ---> 45     r2scores.append(r2_score(y_real.cpu(), y_hat.cpu()))
#
#      46     losses.append(loss)
#
#      47 eval_loss = torch.tensor(losses).mean().item()
#
#
#
# File /usr/local/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#
#     207 try:
#
#     208     with config_context(
#
#     209         skip_parameter_validation=(
#
#     210             prefer_skip_nested_validation or global_skip_validation
#
#     211         )
#
#     212     ):
#
# --> 213         return func(*args, **kwargs)
#
#     214 except InvalidParameterError as e:
#
#     215     # When the function is just a wrapper around an estimator, we allow
#
#     216     # the function to delegate validation to the estimator, but we replace
#
#     217     # the name of the estimator by the name of the function in the error
#
#     218     # message to avoid confusion.
#
#     219     msg = re.sub(
#
#     220         r"parameter of \w+ must be",
#
#     221         f"parameter of {func.__qualname__} must be",
#
#     222         str(e),
#
#     223     )
#
#
#
# File /usr/local/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1180, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#
#    1039 @validate_params(
#
#    1040     {
#
#    1041         "y_true": ["array-like"],
#
#    (...)
#
#    1059     force_finite=True,
#
#    1060 ):
#
#    1061     """:math:`R^2` (coefficient of determination) regression score function.
#
#    1062
#
#    1063     Best possible score is 1.0 and it can be negative (because the
#
#    (...)
#
#    1178     -inf
#
#    1179     """
#
# -> 1180     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#
#    1181         y_true, y_pred, multioutput
#
#    1182     )
#
#    1183     check_consistent_length(y_true, y_pred, sample_weight)
#
#    1185     if _num_samples(y_pred) < 2:
#
#
#
# File /usr/local/lib/python3.12/site-packages/sklearn/metrics/_regression.py:104, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#
#     102 check_consistent_length(y_true, y_pred)
#
#     103 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#
# --> 104 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
#     106 if y_true.ndim == 1:
#
#     107     y_true = y_true.reshape((-1, 1))
#
#
#
# File /usr/local/lib/python3.12/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#
#    1043     raise ValueError(
#
#    1044         "Found array with dim %d. %s expected <= 2."
#
#    1045         % (array.ndim, estimator_name)
#
#    1046     )
#
#    1048 if force_all_finite:
#
# -> 1049     _assert_all_finite(
#
#    1050         array,
#
#    1051         input_name=input_name,
#
#    1052         estimator_name=estimator_name,
#
#    1053         allow_nan=force_all_finite == "allow-nan",
#
#    1054     )
#
#    1056 if copy:
#
#    1057     if _is_numpy_namespace(xp):
#
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
#
#
# File /usr/local/lib/python3.12/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#
#     123 if first_pass_isfinite:
#
#     124     return
#
# --> 126 _assert_all_finite_element_wise(
#
#     127     X,
#
#     128     xp=xp,
#
#     129     allow_nan=allow_nan,
#
#     130     msg_dtype=msg_dtype,
#
#     131     estimator_name=estimator_name,
#
#     132     input_name=input_name,
#
#     133 )
#
#
#
# File /usr/local/lib/python3.12/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#
#     158 if estimator_name and input_name == "X" and has_nan_error:
#
#     159     # Improve the error message on how to handle missing values in
#
#     160     # scikit-learn.
#
#     161     msg_err += (
#
#     162         f"\n{estimator_name} does not accept missing values"
#
#     163         " encoded as NaN natively. For supervised learning, you might want"
#
#    (...)
#
#     173         "#estimators-that-handle-nan-values"
#
#     174     )
#
# --> 175 raise ValueError(msg_err)
#
#
#
# ValueError: Input contains NaN.

# %%
model.eval()
predictions = []
real =[]
losses, r2scores = [], []
for batch in dataloader['test']:
    batch = batch.to(device)
    x = batch.x.view(len(batch), n_nodes, n_features)
    y_hat,h = model(x, e, h)
    loss = F.mse_loss(y_hat.view(-1, n_target), batch.y).item()
    preds = y_hat.view(len(batch), n_nodes, n_target)
    real.append(batch.y.view(len(batch), n_nodes, n_target).cpu())
    predictions.append(preds.cpu().detach().numpy())
    r2scores.append(r2_score(batch.y.detach().cpu(), y_hat.view(-1, n_target).detach().cpu()))
    losses.append(loss)
test_loss = torch.tensor(losses).mean().item()
test_r2score = np.mean(r2scores)

print(f"Test_loss:{test_loss:.4f}, Test_r2:{test_r2score:.4f}")
# Out:
# Test_loss:1.3576, Test_r2:-14.2698

# %%
def reconstruir_predictions(predictions,real, n_target, situacion, n_div):
    id_situacion = situacion*n_div
    temp = np.array(predictions).reshape(-1, n_nodes, n_target)
    temp2 =np.array(real).reshape(-1, n_nodes, n_target)
    return np.concatenate([np.array(temp[id_situacion+i]) for i in range(n_div)], axis=1), np.concatenate([np.array(temp2[id_situacion+i]) for i in range(n_div)], axis=1)

# %%
n_situation = 20

n_plots = 23
n_cols = 2
n_rows = (n_plots + 1) // 2  # División redondeada hacia arriba
preds, y_true = reconstruir_predictions(predictions,real, n_target, n_situation, n_div)
fig, axs = plt.subplots(n_rows, n_cols, figsize=(10, 20),dpi=200)
# Trazar los gráficos
for i in range(n_plots):
    row = i % n_rows  # Calculamos el índice de la fila
    col = i // n_rows  # Calculamos el índice de la columna
    ax = axs[row, col] if n_plots > 1 else axs
    
    ax = axs[row, col] if n_plots > 1 else axs
    
    sns.lineplot(y=y_true[i],x=range(n_target*n_div), ax=ax, label='Real', legend=False, color='royalblue')
    

    sns.lineplot(y=preds[i],x=range(n_target*n_div),ax=ax, label='Predicciones', legend=False)
    
    ax.set_title(f'Nodo {i+1}')
    format_plot(ax)
    # Añadir leyenda solo al último plot
    if i == n_plots - 1:
        ax.legend(loc='upper left')

if n_plots % n_cols != 0:
    fig.delaxes(axs.flatten()[-1])
# Ajustes finales
plt.tight_layout()
plt.show()
