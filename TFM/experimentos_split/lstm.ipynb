# %% [markdown]
# # Experimentación - LSTM
#
#
#
# ## 1. Obtención de datos

# %%
import torch
import torch.nn.functional as F
import pandas as pd
import seaborn as sns
import networkx as nx
sns.set_palette("coolwarm_r")
import matplotlib.pyplot as plt
import numpy as np

from torch_geometric.data import Data, Dataset
from torch_geometric.nn import GCNConv

import os, sys

path = os.getcwd()

sys.path.insert(1, "/".join(path.split("/")[0:-1]))

from utils import powergrid

# %%
#folder_path = "/home/TFM/code_dataset2/datos/Natural Oscillation"
folder_path = "/Users/maguado/Documents/UGR/Master/TFM/datos_2/Natural Oscillation"

# %%
loader = powergrid.PowerGridDatasetLoader(folder_path, problem="regression")
_,_,_ =loader.process()
limit = 300
#dataset_full = loader.get_dataset( target= 20, intro=300, step=20, limit=limit, one_ts_per_situation=False)
# Out:
# Processing:  row_307
# Node:  0  not included, including...
# Node:  1  not included, including...
# Node:  2  not included, including...
# Node:  3  not included, including...
# Node:  4  not included, including...
# Node:  5  not included, including...
# Node:  6  not included, including...
# Node:  7  not included, including...
# Node:  8  not included, including...
# Node:  9  not included, including...
# Node:  10  not included, including...
# Node:  11  not included, including...
# Node:  12  not included, including...
# Node:  13  not included, including...
# Node:  14  not included, including...
# Node:  15  not included, including...
# Node:  16  not included, including...
# Node:  17  not included, including...
# Node:  18  not included, including...
# Node:  19  not included, including...
# Node:  20  not included, including...
# Node:  21  not included, including...
# Node:  22  not included, including...
# Processing:  row_135
# Processing:  row_75
# Processing:  row_338
# Processing:  row_81
# Processing:  row_132
# Processing:  row_300
# Processing:  row_86
# Processing:  row_72
# Processing:  row_104
# Processing:  row_336
# Processing:  row_309
# Processing:  row_44
# Processing:  row_331
# Processing:  row_88
# Processing:  row_103
# Processing:  row_43
# Processing:  row_17
# Processing:  row_168
# Processing:  row_28
# Processing:  row_391
# Processing:  row_157
# Processing:  row_365
# Processing:  row_533
# Processing:  row_10
# Processing:  row_534
# Processing:  row_362
# Processing:  row_150
# Processing:  row_396
# Processing:  row_159
# Processing:  row_26
# Processing:  row_354
# Processing:  row_166
# Processing:  row_502
# Processing:  row_19
# Processing:  row_192
# Processing:  row_21
# Processing:  row_398
# Processing:  row_195
# Processing:  row_505
# Processing:  row_161
# Processing:  row_353
# Processing:  row_102
# Processing:  row_330
# Processing:  row_89
# Processing:  row_42
# Processing:  row_337
# Processing:  row_105
# Processing:  row_45
# Processing:  row_308
# Processing:  row_301
# Processing:  row_133
# Processing:  row_73
# Processing:  row_87
# Processing:  row_550
# Processing:  row_134
# Processing:  row_306
# Processing:  row_339
# Processing:  row_80
# Processing:  row_74
# Processing:  row_20
# Processing:  row_399
# Processing:  row_504
# Processing:  row_352
# Processing:  row_160
# Processing:  row_194
# Processing:  row_27
# Processing:  row_158
# Processing:  row_193
# Processing:  row_18
# Processing:  row_167
# Processing:  row_355
# Processing:  row_503
# Processing:  row_11
# Processing:  row_397
# Processing:  row_535
# Processing:  row_151
# Processing:  row_363
# Processing:  row_169
# Processing:  row_16
# Processing:  row_364
# Processing:  row_156
# Processing:  row_532
# Processing:  row_29
# Processing:  row_390
# Processing:  row_440
# Processing:  row_216
# Processing:  row_229
# Processing:  row_211
# Processing:  row_447
# Processing:  row_478
# Processing:  row_471
# Processing:  row_227
# Processing:  row_485
# Processing:  row_218
# Processing:  row_482
# Processing:  row_220
# Processing:  row_476
# Processing:  row_449
# Processing:  row_280
# Processing:  row_274
# Processing:  row_422
# Processing:  row_425
# Processing:  row_273
# Processing:  row_287
# Processing:  row_245
# Processing:  row_413
# Processing:  row_289
# Processing:  row_414
# Processing:  row_242
# Processing:  row_221
# Processing:  row_477
# Processing:  row_483
# Processing:  row_448
# Processing:  row_484
# Processing:  row_470
# Processing:  row_226
# Processing:  row_219
# Processing:  row_210
# Processing:  row_446
# Processing:  row_479
# Processing:  row_441
# Processing:  row_217
# Processing:  row_228
# Processing:  row_288
# Processing:  row_415
# Processing:  row_243
# Processing:  row_244
# Processing:  row_412
# Processing:  row_286
# Processing:  row_424
# Processing:  row_272
# Processing:  row_275
# Processing:  row_423
# Processing:  row_281
# Processing:  row_401
# Processing:  row_257
# Processing:  row_268
# Processing:  row_3
# Processing:  row_250
# Processing:  row_406
# Processing:  row_439
# Processing:  row_4
# Processing:  row_292
# Processing:  row_430
# Processing:  row_266
# Processing:  row_259
# Processing:  row_261
# Processing:  row_437
# Processing:  row_295
# Processing:  row_408
# Processing:  row_235
# Processing:  row_463
# Processing:  row_497
# Processing:  row_490
# Processing:  row_464
# Processing:  row_232
# Processing:  row_499
# Processing:  row_204
# Processing:  row_452
# Processing:  row_455
# Processing:  row_203
# Processing:  row_294
# Processing:  row_260
# Processing:  row_436
# Processing:  row_409
# Processing:  row_431
# Processing:  row_267
# Processing:  row_293
# Processing:  row_258
# Processing:  row_251
# Processing:  row_407
# Processing:  row_438
# Processing:  row_5
# Processing:  row_400
# Processing:  row_256
# Processing:  row_2
# Processing:  row_269
# Processing:  row_454
# Processing:  row_202
# Processing:  row_498
# Processing:  row_205
# Processing:  row_453
# Processing:  row_465
# Processing:  row_233
# Processing:  row_491
# Processing:  row_496
# Processing:  row_234
# Processing:  row_462
# Processing:  row_510
# Processing:  row_174
# Processing:  row_346
# Processing:  row_180
# Processing:  row_379
# Processing:  row_34
# Processing:  row_187
# Processing:  row_341
# Processing:  row_173
# Processing:  row_517
# Processing:  row_33
# Processing:  row_528
# Processing:  row_383
# Processing:  row_521
# Processing:  row_377
# Processing:  row_145
# Processing:  row_348
# Processing:  row_142
# Processing:  row_370
# Processing:  row_526
# Processing:  row_384
# Processing:  row_519
# Processing:  row_189
# Processing:  row_129
# Processing:  row_56
# Processing:  row_324
# Processing:  row_116
# Processing:  row_69
# Processing:  row_51
# Processing:  row_111
# Processing:  row_323
# Processing:  row_67
# Processing:  row_93
# Processing:  row_118
# Processing:  row_58
# Processing:  row_127
# Processing:  row_315
# Processing:  row_543
# Processing:  row_94
# Processing:  row_60
# Processing:  row_544
# Processing:  row_312
# Processing:  row_120
# Processing:  row_385
# Processing:  row_371
# Processing:  row_143
# Processing:  row_527
# Processing:  row_188
# Processing:  row_518
# Processing:  row_520
# Processing:  row_144
# Processing:  row_376
# Processing:  row_382
# Processing:  row_349
# Processing:  row_172
# Processing:  row_340
# Processing:  row_516
# Processing:  row_186
# Processing:  row_529
# Processing:  row_32
# Processing:  row_181
# Processing:  row_511
# Processing:  row_347
# Processing:  row_175
# Processing:  row_35
# Processing:  row_378
# Processing:  row_61
# Processing:  row_95
# Processing:  row_545
# Processing:  row_121
# Processing:  row_313
# Processing:  row_119
# Processing:  row_92
# Processing:  row_66
# Processing:  row_314
# Processing:  row_126
# Processing:  row_542
# Processing:  row_59
# Processing:  row_50
# Processing:  row_322
# Processing:  row_110
# Processing:  row_57
# Processing:  row_128
# Processing:  row_68
# Processing:  row_117
# Processing:  row_325
# Processing:  row_508
# Processing:  row_13
# Processing:  row_198
# Processing:  row_537
# Processing:  row_153
# Processing:  row_361
# Processing:  row_395
# Processing:  row_14
# Processing:  row_359
# Processing:  row_392
# Processing:  row_366
# Processing:  row_154
# Processing:  row_530
# Processing:  row_22
# Processing:  row_539
# Processing:  row_196
# Processing:  row_506
# Processing:  row_350
# Processing:  row_162
# Processing:  row_368
# Processing:  row_25
# Processing:  row_165
# Processing:  row_357
# Processing:  row_501
# Processing:  row_191
# Processing:  row_303
# Processing:  row_131
# Processing:  row_85
# Processing:  row_71
# Processing:  row_49
# Processing:  row_136
# Processing:  row_304
# Processing:  row_76
# Processing:  row_82
# Processing:  row_109
# Processing:  row_100
# Processing:  row_332
# Processing:  row_40
# Processing:  row_335
# Processing:  row_107
# Processing:  row_78
# Processing:  row_138
# Processing:  row_47
# Processing:  row_24
# Processing:  row_369
# Processing:  row_190
# Processing:  row_356
# Processing:  row_164
# Processing:  row_500
# Processing:  row_538
# Processing:  row_23
# Processing:  row_507
# Processing:  row_163
# Processing:  row_351
# Processing:  row_197
# Processing:  row_358
# Processing:  row_15
# Processing:  row_155
# Processing:  row_367
# Processing:  row_531
# Processing:  row_393
# Processing:  row_199
# Processing:  row_12
# Processing:  row_509
# Processing:  row_394
# Processing:  row_536
# Processing:  row_360
# Processing:  row_152
# Processing:  row_79
# Processing:  row_106
# Processing:  row_334
# Processing:  row_46
# Processing:  row_139
# Processing:  row_333
# Processing:  row_101
# Processing:  row_41
# Processing:  row_305
# Processing:  row_137
# Processing:  row_48
# Processing:  row_108
# Processing:  row_83
# Processing:  row_77
# Processing:  row_130
# Processing:  row_302
# Processing:  row_70
# Processing:  row_84
# Processing:  row_419
# Processing:  row_426
# Processing:  row_270
# Processing:  row_284
# Processing:  row_248
# Processing:  row_283
# Processing:  row_277
# Processing:  row_421
# Processing:  row_428
# Processing:  row_417
# Processing:  row_241
# Processing:  row_279
# Processing:  row_246
# Processing:  row_410
# Processing:  row_212
# Processing:  row_444
# Processing:  row_443
# Processing:  row_215
# Processing:  row_488
# Processing:  row_481
# Processing:  row_223
# Processing:  row_475
# Processing:  row_472
# Processing:  row_224
# Processing:  row_486
# Processing:  row_278
# Processing:  row_247
# Processing:  row_411
# Processing:  row_429
# Processing:  row_416
# Processing:  row_240
# Processing:  row_249
# Processing:  row_276
# Processing:  row_420
# Processing:  row_282
# Processing:  row_418
# Processing:  row_285
# Processing:  row_427
# Processing:  row_271
# Processing:  row_487
# Processing:  row_473
# Processing:  row_225
# Processing:  row_222
# Processing:  row_474
# Processing:  row_480
# Processing:  row_442
# Processing:  row_214
# Processing:  row_489
# Processing:  row_213
# Processing:  row_445
# Processing:  row_458
# Processing:  row_493
# Processing:  row_467
# Processing:  row_231
# Processing:  row_209
# Processing:  row_236
# Processing:  row_460
# Processing:  row_494
# Processing:  row_469
# Processing:  row_456
# Processing:  row_200
# Processing:  row_238
# Processing:  row_207
# Processing:  row_451
# Processing:  row_253
# Processing:  row_405
# Processing:  row_298
# Processing:  row_7
# Processing:  row_402
# Processing:  row_254
# Processing:  row_262
# Processing:  row_9
# Processing:  row_434
# Processing:  row_296
# Processing:  row_291
# Processing:  row_433
# Processing:  row_265
# Processing:  row_239
# Processing:  row_206
# Processing:  row_450
# Processing:  row_468
# Processing:  row_457
# Processing:  row_201
# Processing:  row_208
# Processing:  row_495
# Processing:  row_237
# Processing:  row_461
# Processing:  row_459
# Processing:  row_466
# Processing:  row_230
# Processing:  row_492
# Processing:  row_432
# Processing:  row_264
# Processing:  row_290
# Processing:  row_297
# Processing:  row_8
# Processing:  row_263
# Processing:  row_435
# Processing:  row_403
# Processing:  row_255
# Processing:  row_1
# Processing:  row_252
# Processing:  row_404
# Processing:  row_6
# Processing:  row_299
# Processing:  row_52
# Processing:  row_549
# Processing:  row_99
# Processing:  row_320
# Processing:  row_112
# Processing:  row_318
# Processing:  row_55
# Processing:  row_115
# Processing:  row_327
# Processing:  row_97
# Processing:  row_63
# Processing:  row_547
# Processing:  row_123
# Processing:  row_311
# Processing:  row_64
# Processing:  row_90
# Processing:  row_329
# Processing:  row_316
# Processing:  row_124
# Processing:  row_540
# Processing:  row_184
# Processing:  row_170
# Processing:  row_342
# Processing:  row_514
# Processing:  row_389
# Processing:  row_30
# Processing:  row_513
# Processing:  row_345
# Processing:  row_177
# Processing:  row_183
# Processing:  row_148
# Processing:  row_37
# Processing:  row_373
# Processing:  row_141
# Processing:  row_525
# Processing:  row_387
# Processing:  row_380
# Processing:  row_39
# Processing:  row_522
# Processing:  row_146
# Processing:  row_374
# Processing:  row_179
# Processing:  row_91
# Processing:  row_328
# Skipping  row_328
# Processing:  row_65
# Processing:  row_125
# Processing:  row_317
# Processing:  row_541
# Processing:  row_62
# Processing:  row_96
# Processing:  row_546
# Processing:  row_310
# Processing:  row_122
# Processing:  row_54
# Processing:  row_319
# Processing:  row_326
# Processing:  row_114
# Processing:  row_548
# Processing:  row_53
# Processing:  row_113
# Processing:  row_98
# Processing:  row_321
# Processing:  row_523
# Processing:  row_375
# Processing:  row_147
# Processing:  row_381
# Processing:  row_38
# Processing:  row_178
# Processing:  row_386
# Processing:  row_140
# Processing:  row_372
# Processing:  row_524
# Processing:  row_182
# Processing:  row_512
# Processing:  row_176
# Processing:  row_344
# Processing:  row_36
# Processing:  row_149
# Processing:  row_343
# Processing:  row_171
# Processing:  row_515
# Processing:  row_185
# Processing:  row_388
# Processing:  row_31

# %% [markdown]
# ## Funciones auxiliares - entrenamiento

# %%
from utils import pygt_loader

try:
    from tqdm import tqdm
except ImportError:
    def tqdm(iterable):
        return iterable
import os
import torch
import torch.nn.functional as F
from torch_geometric_temporal.nn.recurrent import AGCRN
from utils.utils_graph import format_plot, plot_training_and_eval_losses, plot_predictions
from utils.general_nn import guardar_resultados

from torch.optim.lr_scheduler import ReduceLROnPlateau
from utils.utils_graph import format_plot
from utils import train_lstm
from utils import trainer
import utils.train_lstm
dtype = torch.float
device = torch.device("cpu")

# %% [markdown]
# ## Prueba - predicción por tipos

# %% [markdown]
# ### Gen trip

# %%
problem = "gen_trip"
dataset_gt, situations_gt = loader.get_dataset( target= 20, intro=100, step=20, one_ts_per_situation=False, start = 1, type=problem)
# Out:
# Number of situations:  549
# Number of timestamps:  800
# Number of situations of the selected type:  184

# %%
n_div_gt = loader.div

# %% [markdown]
# #### Sencilla

# %%
dataloader_params2 = {
            "batch_size": 5,
            "data_split_ratio": [0.7, 0.15, 0.15],
            "seed": 42,
            "keep_same": True,
            "use_batch":True
}

params_model = {
    "hidden_size": 50,
    "n_layers": 2
}

dataloader_gt = trainer.train_test_val_split(dataset_gt, 
                                          batch_size=dataloader_params2["batch_size"], 
                                          data_split_ratio=dataloader_params2["data_split_ratio"], 
                                          random_seed=dataloader_params2["seed"], 
                                          keep_same=dataloader_params2["keep_same"], 
                                          use_batch=dataloader_params2["use_batch"])

model_gt, losses_gt, eval_losses_gt, r2scores_eval_gt = train_lstm.train_lstm_model(dataset_gt, params_model, dataloader_gt, num_epochs=30, lr=0.001, problem=problem, save_model = False, path_save = "./results" )
# Out:
# ==================== DATASET INFO ===================
#
# Train dataset: 4350
# Validation dataset: 930
# Test dataset: 942
#
# ==================== DATALOADER INFO ===================
#
# DataLoader for train set:
# Number of batches: 870
# DataLoader for val set:
# Number of batches: 186
# DataLoader for test set:
# Number of batches: 188
#
# ==================== TRAIN ===================
#
# Epoch 1/30 | Train Loss: 0.0510 | Eval Loss: 0.0845 | Eval R2: -8.2851 |
# Epoch 2/30 | Train Loss: 0.0138 | Eval Loss: 0.0845 | Eval R2: -8.1360 |
# Epoch 3/30 | Train Loss: 0.0121 | Eval Loss: 0.0855 | Eval R2: -8.1906 |
# Epoch 4/30 | Train Loss: 0.0114 | Eval Loss: 0.0863 | Eval R2: -8.2660 |
# Epoch 5/30 | Train Loss: 0.0110 | Eval Loss: 0.0863 | Eval R2: -8.2862 |
# Epoch 6/30 | Train Loss: 0.0107 | Eval Loss: 0.0851 | Eval R2: -8.1323 |
# Epoch 7/30 | Train Loss: 0.0102 | Eval Loss: 0.0840 | Eval R2: -8.0339 |
# Epoch 8/30 | Train Loss: 0.0100 | Eval Loss: 0.0840 | Eval R2: -7.9828 |
# Epoch 9/30 | Train Loss: 0.0097 | Eval Loss: 0.0853 | Eval R2: -8.0030 |
# Epoch 10/30 | Train Loss: 0.0095 | Eval Loss: 0.0851 | Eval R2: -7.9768 |
# Epoch 11/30 | Train Loss: 0.0093 | Eval Loss: 0.0853 | Eval R2: -8.0667 |
# Epoch 12/30 | Train Loss: 0.0091 | Eval Loss: 0.0860 | Eval R2: -8.1651 |
# Epoch 13/30 | Train Loss: 0.0090 | Eval Loss: 0.0858 | Eval R2: -8.1950 |
# Epoch 14/30 | Train Loss: 0.0088 | Eval Loss: 0.0863 | Eval R2: -8.1291 |
# Epoch 15/30 | Train Loss: 0.0084 | Eval Loss: 0.0870 | Eval R2: -8.1921 |
# Epoch 16/30 | Train Loss: 0.0083 | Eval Loss: 0.0866 | Eval R2: -8.1337 |
# Epoch 17/30 | Train Loss: 0.0083 | Eval Loss: 0.0871 | Eval R2: -8.2061 |
# Epoch 18/30 | Train Loss: 0.0083 | Eval Loss: 0.0872 | Eval R2: -8.1945 |
# Epoch 19/30 | Train Loss: 0.0083 | Eval Loss: 0.0868 | Eval R2: -8.1739 |
# Epoch 20/30 | Train Loss: 0.0083 | Eval Loss: 0.0867 | Eval R2: -8.1543 |
# Epoch 21/30 | Train Loss: 0.0079 | Eval Loss: 0.0861 | Eval R2: -8.0758 |
# Epoch 22/30 | Train Loss: 0.0079 | Eval Loss: 0.0871 | Eval R2: -8.1713 |
# Epoch 23/30 | Train Loss: 0.0079 | Eval Loss: 0.0868 | Eval R2: -8.1200 |
# Epoch 24/30 | Train Loss: 0.0076 | Eval Loss: 0.0870 | Eval R2: -8.1608 |
# Epoch 25/30 | Train Loss: 0.0076 | Eval Loss: 0.0866 | Eval R2: -8.1105 |
# Epoch 26/30 | Train Loss: 0.0075 | Eval Loss: 0.0866 | Eval R2: -8.1192 |
# Epoch 27/30 | Train Loss: 0.0074 | Eval Loss: 0.0868 | Eval R2: -8.1296 |
# Epoch 28/30 | Train Loss: 0.0078 | Eval Loss: 0.0862 | Eval R2: -8.0608 |
# Epoch 29/30 | Train Loss: 0.0074 | Eval Loss: 0.0874 | Eval R2: -8.2047 |
# Epoch 30/30 | Train Loss: 0.0071 | Eval Loss: 0.0869 | Eval R2: -8.1372 |
# Entrenamiento completado.

# %%
plot_training_and_eval_losses(np.array(losses_gt), np.array(eval_losses_gt), 30, format_plot)

# %%
r2score_tst, losses_tst, loss_nodes, predictions, real = train_lstm.test(model_gt, dataloader_gt)
# Out:
# ==================== TEST INFO ===================
#
# Test_loss:0.0074, Test_r2:0.3582

# %%
plot_predictions(predictions, real, 20, 20, n_div_gt, problem)

# %%
resultados = {
    "loss_test": np.mean(losses_tst),
    "r2_test": np.mean(r2score_tst),
    "loss_nodes" : np.mean(loss_nodes, axis=0),
    "r2_eval_final": r2scores_eval_gt[-1],
    "loss_eval_final": eval_losses_gt[-1],
    "loss_final": losses_gt[-1]
}


guardar_resultados(model_gt, "LSTM", problem, resultados_mejor_modelo=resultados, results_path = "./results",path_save_experiment=None, params=None)
# Out:
# ==================== GUARDANDO RESULTADOS ===================
#
#   Modelo Params Fichero_resultados_experimento  Loss_tst   R2_tst  \
# 0   LSTM    NaN                            NaN  0.007442  0.35825
# 1   LSTM   None                           None  0.007442  0.35825
#
#                                           Loss_nodes  R2_eval  Loss_eval  \
# 0  [0.00292401 0.00315184 0.00446385 0.0074707  0... -8.13717   0.086898
# 1  [0.0029240102, 0.0031518377, 0.00446385, 0.007... -8.13717   0.086898
#
#    Loss_final
# 0    0.007102
# 1    0.007102
#
# ==================== RESULTADOS GUARDADOS ===================

# %% [markdown]
# ### Bus trip

# %%
problem = "bus_trip"
dataset_bt, situations_bt = loader.get_dataset( target= 20, intro=100, step=20, one_ts_per_situation=False, start = 1, type=problem)
# Out:
# Number of situations:  549
# Number of timestamps:  800
# Number of situations of the selected type:  86

# %%
n_div_bt = loader.div

# %% [markdown]
# #### Sencilla

# %%
dataloader_params2 = {
            "batch_size": 5,
            "data_split_ratio": [0.7, 0.15, 0.15],
            "seed": 42,
            "keep_same": True,
            "use_batch":True
}

params_model = {
    "hidden_size": 50,
    "n_layers": 2
}

dataloader_bt = trainer.train_test_val_split(dataset_bt, 
                                          batch_size=dataloader_params2["batch_size"], 
                                          data_split_ratio=dataloader_params2["data_split_ratio"], 
                                          random_seed=dataloader_params2["seed"], 
                                          keep_same=dataloader_params2["keep_same"], 
                                          use_batch=dataloader_params2["use_batch"])

model_bt, losses_bt, eval_losses_bt, r2scores_eval_bt = train_lstm.train_lstm_model(dataset_bt, params_model, dataloader_bt, num_epochs=30, lr=0.001, problem=problem, save_model = False, path_save = "./results" )
# Out:
# ==================== DATASET INFO ===================
#
# Train dataset: 2025
# Validation dataset: 435
# Test dataset: 430
#
# ==================== DATALOADER INFO ===================
#
# DataLoader for train set:
# Number of batches: 405
# DataLoader for val set:
# Number of batches: 87
# DataLoader for test set:
# Number of batches: 86
#
# ==================== TRAIN ===================
#
# Epoch 1/30 | Train Loss: 0.0807 | Eval Loss: 0.1505 | Eval R2: -1.5207 |
# Epoch 2/30 | Train Loss: 0.0109 | Eval Loss: 0.1559 | Eval R2: -1.6029 |
# Epoch 3/30 | Train Loss: 0.0093 | Eval Loss: 0.1593 | Eval R2: -1.6517 |
# Epoch 4/30 | Train Loss: 0.0083 | Eval Loss: 0.1609 | Eval R2: -1.6757 |
# Epoch 5/30 | Train Loss: 0.0077 | Eval Loss: 0.1610 | Eval R2: -1.6784 |
# Epoch 6/30 | Train Loss: 0.0073 | Eval Loss: 0.1610 | Eval R2: -1.6766 |
# Epoch 7/30 | Train Loss: 0.0069 | Eval Loss: 0.1613 | Eval R2: -1.6812 |
# Epoch 8/30 | Train Loss: 0.0067 | Eval Loss: 0.1610 | Eval R2: -1.6750 |
# Epoch 9/30 | Train Loss: 0.0065 | Eval Loss: 0.1609 | Eval R2: -1.6732 |
# Epoch 10/30 | Train Loss: 0.0063 | Eval Loss: 0.1612 | Eval R2: -1.6779 |
# Epoch 11/30 | Train Loss: 0.0061 | Eval Loss: 0.1611 | Eval R2: -1.6749 |
# Epoch 12/30 | Train Loss: 0.0060 | Eval Loss: 0.1609 | Eval R2: -1.6715 |
# Epoch 13/30 | Train Loss: 0.0059 | Eval Loss: 0.1608 | Eval R2: -1.6706 |
# Epoch 14/30 | Train Loss: 0.0057 | Eval Loss: 0.1609 | Eval R2: -1.6700 |
# Epoch 15/30 | Train Loss: 0.0056 | Eval Loss: 0.1614 | Eval R2: -1.6756 |
# Epoch 16/30 | Train Loss: 0.0055 | Eval Loss: 0.1620 | Eval R2: -1.6845 |
# Epoch 17/30 | Train Loss: 0.0055 | Eval Loss: 0.1626 | Eval R2: -1.6925 |
# Epoch 18/30 | Train Loss: 0.0055 | Eval Loss: 0.1635 | Eval R2: -1.7057 |
# Epoch 19/30 | Train Loss: 0.0053 | Eval Loss: 0.1641 | Eval R2: -1.7127 |
# Epoch 20/30 | Train Loss: 0.0052 | Eval Loss: 0.1645 | Eval R2: -1.7179 |
# Epoch 21/30 | Train Loss: 0.0051 | Eval Loss: 0.1646 | Eval R2: -1.7189 |
# Epoch 22/30 | Train Loss: 0.0049 | Eval Loss: 0.1645 | Eval R2: -1.7187 |
# Epoch 23/30 | Train Loss: 0.0049 | Eval Loss: 0.1647 | Eval R2: -1.7224 |
# Epoch 24/30 | Train Loss: 0.0048 | Eval Loss: 0.1648 | Eval R2: -1.7248 |
# Epoch 25/30 | Train Loss: 0.0048 | Eval Loss: 0.1649 | Eval R2: -1.7267 |
# Epoch 26/30 | Train Loss: 0.0047 | Eval Loss: 0.1647 | Eval R2: -1.7248 |
# Epoch 27/30 | Train Loss: 0.0046 | Eval Loss: 0.1647 | Eval R2: -1.7261 |
# Epoch 28/30 | Train Loss: 0.0046 | Eval Loss: 0.1644 | Eval R2: -1.7213 |
# Epoch 29/30 | Train Loss: 0.0046 | Eval Loss: 0.1644 | Eval R2: -1.7213 |
# Epoch 30/30 | Train Loss: 0.0045 | Eval Loss: 0.1640 | Eval R2: -1.7151 |
# Entrenamiento completado.

# %%
plot_training_and_eval_losses(np.array(losses_bt), np.array(eval_losses_bt), 30, format_plot)

# %%
r2score_tst_bt, losses_tst_bt, loss_nodes_bt, predictions_bt, real_bt = train_lstm.test(model_bt, dataloader_bt)
# Out:
# ==================== TEST INFO ===================
#
# Test_loss:0.0051, Test_r2:0.9249

# %%
plot_predictions(predictions_bt, real_bt, 20, 0, n_div_bt, problem)

# %%
resultados_bt = {
    "loss_test": np.mean(losses_tst_bt),
    "r2_test": np.mean(r2score_tst_bt),
    "loss_nodes" : np.mean(loss_nodes_bt, axis=0),
    "r2_eval_final": r2scores_eval_bt[-1],
    "loss_eval_final": eval_losses_bt[-1],
    "loss_final": losses_bt[-1]
}


guardar_resultados(model_bt, "LSTM", problem, resultados_mejor_modelo=resultados_bt, results_path = "./results",path_save_experiment=None, params=None)
# Out:
# ==================== GUARDANDO RESULTADOS ===================
#
#   Modelo Params Fichero_resultados_experimento  Loss_tst    R2_tst  \
# 0   LSTM   None                           None  0.005105  0.924924
#
#                                           Loss_nodes   R2_eval  Loss_eval  \
# 0  [0.0032101588, 0.0040684757, 0.0036459237, 0.0... -1.715052   0.163971
#
#    Loss_final
# 0    0.004536
#
# ==================== RESULTADOS GUARDADOS ===================

# %% [markdown]
# ### Bus fault

# %%
problem = "bus_fault"
dataset_bf, situations_bf = loader.get_dataset( target= 20, intro=100, step=20, one_ts_per_situation=False, start = 1, type=problem)
# Out:
# Number of situations:  549
# Number of timestamps:  800
# Number of situations of the selected type:  86

# %%
n_div_bf = loader.div

# %% [markdown]
# #### Sencilla

# %%
dataloader_params2 = {
            "batch_size": 5,
            "data_split_ratio": [0.7, 0.15, 0.15],
            "seed": 42,
            "keep_same": True,
            "use_batch":True
}

params_model = {
    "hidden_size": 50,
    "n_layers": 2
}

dataloader_bf = trainer.train_test_val_split(dataset_bf, 
                                          batch_size=dataloader_params2["batch_size"], 
                                          data_split_ratio=dataloader_params2["data_split_ratio"], 
                                          random_seed=dataloader_params2["seed"], 
                                          keep_same=dataloader_params2["keep_same"], 
                                          use_batch=dataloader_params2["use_batch"])

model_bf, losses_bf, eval_losses_bf, r2scores_eval_bf = train_lstm.train_lstm_model(dataset_bf, params_model, dataloader_bf, num_epochs=30, lr=0.001, problem=problem, save_model = False, path_save = "./results" )
# Out:
# ==================== DATASET INFO ===================
#
# Train dataset: 2025
# Validation dataset: 435
# Test dataset: 430
#
# ==================== DATALOADER INFO ===================
#
# DataLoader for train set:
# Number of batches: 405
# DataLoader for val set:
# Number of batches: 87
# DataLoader for test set:
# Number of batches: 86
#
# ==================== TRAIN ===================
#
# Epoch 1/30 | Train Loss: 0.0753 | Eval Loss: 0.1809 | Eval R2: -7.6364 |
# Epoch 2/30 | Train Loss: 0.0280 | Eval Loss: 0.1813 | Eval R2: -7.6012 |
# Epoch 3/30 | Train Loss: 0.0259 | Eval Loss: 0.1816 | Eval R2: -7.5958 |
# Epoch 4/30 | Train Loss: 0.0244 | Eval Loss: 0.1819 | Eval R2: -7.6031 |
# Epoch 5/30 | Train Loss: 0.0234 | Eval Loss: 0.1818 | Eval R2: -7.5359 |
# Epoch 6/30 | Train Loss: 0.0227 | Eval Loss: 0.1818 | Eval R2: -7.5148 |
# Epoch 7/30 | Train Loss: 0.0224 | Eval Loss: 0.1819 | Eval R2: -7.5490 |
# Epoch 8/30 | Train Loss: 0.0218 | Eval Loss: 0.1816 | Eval R2: -7.4947 |
# Epoch 9/30 | Train Loss: 0.0210 | Eval Loss: 0.1817 | Eval R2: -7.4924 |
# Epoch 10/30 | Train Loss: 0.0205 | Eval Loss: 0.1815 | Eval R2: -7.4245 |
# Epoch 11/30 | Train Loss: 0.0206 | Eval Loss: 0.1818 | Eval R2: -7.4678 |
# Epoch 12/30 | Train Loss: 0.0200 | Eval Loss: 0.1808 | Eval R2: -7.3757 |
# Epoch 13/30 | Train Loss: 0.0196 | Eval Loss: 0.1804 | Eval R2: -7.3279 |
# Epoch 14/30 | Train Loss: 0.0197 | Eval Loss: 0.1805 | Eval R2: -7.3550 |
# Epoch 15/30 | Train Loss: 0.0191 | Eval Loss: 0.1801 | Eval R2: -7.3021 |
# Epoch 16/30 | Train Loss: 0.0192 | Eval Loss: 0.1797 | Eval R2: -7.2456 |
# Epoch 17/30 | Train Loss: 0.0190 | Eval Loss: 0.1796 | Eval R2: -7.2942 |
# Epoch 18/30 | Train Loss: 0.0188 | Eval Loss: 0.1800 | Eval R2: -7.4047 |
# Epoch 19/30 | Train Loss: 0.0182 | Eval Loss: 0.1803 | Eval R2: -7.3793 |
# Epoch 20/30 | Train Loss: 0.0184 | Eval Loss: 0.1794 | Eval R2: -7.3714 |
# Epoch 21/30 | Train Loss: 0.0182 | Eval Loss: 0.1805 | Eval R2: -7.4771 |
# Epoch 22/30 | Train Loss: 0.0181 | Eval Loss: 0.1803 | Eval R2: -7.5146 |
# Epoch 23/30 | Train Loss: 0.0185 | Eval Loss: 0.1810 | Eval R2: -7.5476 |
# Epoch 24/30 | Train Loss: 0.0177 | Eval Loss: 0.1815 | Eval R2: -7.6066 |
# Epoch 25/30 | Train Loss: 0.0180 | Eval Loss: 0.1821 | Eval R2: -7.6278 |
# Epoch 26/30 | Train Loss: 0.0175 | Eval Loss: 0.1814 | Eval R2: -7.6084 |
# Epoch 27/30 | Train Loss: 0.0171 | Eval Loss: 0.1814 | Eval R2: -7.6032 |
# Epoch 28/30 | Train Loss: 0.0174 | Eval Loss: 0.1814 | Eval R2: -7.5946 |
# Epoch 29/30 | Train Loss: 0.0171 | Eval Loss: 0.1826 | Eval R2: -7.6858 |
# Epoch 30/30 | Train Loss: 0.0166 | Eval Loss: 0.1818 | Eval R2: -7.6548 |
# Entrenamiento completado.

# %%
plot_training_and_eval_losses(np.array(losses_bf), np.array(eval_losses_bf), 30, format_plot)

# %%
r2score_tst_bf, losses_tst_bf, loss_nodes_bf, predictions_bf, real_bf = train_lstm.test(model_bf, dataloader_bf)
# Out:
# ==================== TEST INFO ===================
#
# Test_loss:0.0169, Test_r2:0.6020

# %%
plot_predictions(predictions_bf, real_bf, 20, 0, n_div_bf, problem)

# %%
resultados_bf = {
    "loss_test": np.mean(losses_tst_bf),
    "r2_test": np.mean(r2score_tst_bf),
    "loss_nodes" : np.mean(loss_nodes_bf, axis=0),
    "r2_eval_final": r2scores_eval_bf[-1],
    "loss_eval_final": eval_losses_bf[-1],
    "loss_final": losses_bf[-1]
}


guardar_resultados(model_bf, "LSTM", problem, resultados_mejor_modelo=resultados_bf, results_path = "./results",path_save_experiment=None, params=None)
# Out:
# ==================== GUARDANDO RESULTADOS ===================
#
#   Modelo Params Fichero_resultados_experimento  Loss_tst    R2_tst  \
# 0   LSTM   None                           None  0.016884  0.601978
#
#                                           Loss_nodes   R2_eval  Loss_eval  \
# 0  [0.011736289, 0.0099513205, 0.0126239, 0.01929... -7.654841   0.181827
#
#    Loss_final
# 0    0.016603
#
# ==================== RESULTADOS GUARDADOS ===================

# %% [markdown]
# ### Branch Fault

# %%
problem = "branch_fault"
dataset_brf, situations_brf = loader.get_dataset( target= 20, intro=100, step=20, one_ts_per_situation=False, start = 1, type=problem)
# Out:
# Number of situations:  549
# Number of timestamps:  800
# Number of situations of the selected type:  92

# %%
n_div_brf = loader.div

# %% [markdown]
# #### Sencilla

# %%
dataloader_params2 = {
            "batch_size": 5,
            "data_split_ratio": [0.7, 0.15, 0.15],
            "seed": 42,
            "keep_same": True,
            "use_batch":True
}

params_model = {
    "hidden_size": 50,
    "n_layers": 2
}

dataloader_brf = trainer.train_test_val_split(dataset_brf, 
                                          batch_size=dataloader_params2["batch_size"], 
                                          data_split_ratio=dataloader_params2["data_split_ratio"], 
                                          random_seed=dataloader_params2["seed"], 
                                          keep_same=dataloader_params2["keep_same"], 
                                          use_batch=dataloader_params2["use_batch"])

model_brf, losses_brf, eval_losses_brf, r2scores_eval_brf = train_lstm.train_lstm_model(dataset_brf, params_model, dataloader_brf, num_epochs=30, lr=0.001, problem=problem, save_model = False, path_save = "./results" )
# Out:
# ==================== DATASET INFO ===================
#
# Train dataset: 2160
# Validation dataset: 465
# Test dataset: 469
#
# ==================== DATALOADER INFO ===================
#
# DataLoader for train set:
# Number of batches: 432
# DataLoader for val set:
# Number of batches: 93
# DataLoader for test set:
# Number of batches: 93
#
# ==================== TRAIN ===================
#
# Epoch 1/30 | Train Loss: 0.0659 | Eval Loss: 0.2168 | Eval R2: -4.4813 |
# Epoch 2/30 | Train Loss: 0.0293 | Eval Loss: 0.2184 | Eval R2: -4.5150 |
# Epoch 3/30 | Train Loss: 0.0267 | Eval Loss: 0.2246 | Eval R2: -4.6620 |
# Epoch 4/30 | Train Loss: 0.0258 | Eval Loss: 0.2302 | Eval R2: -4.7938 |
# Epoch 5/30 | Train Loss: 0.0251 | Eval Loss: 0.2274 | Eval R2: -4.7240 |
# Epoch 6/30 | Train Loss: 0.0238 | Eval Loss: 0.2296 | Eval R2: -4.7767 |
# Epoch 7/30 | Train Loss: 0.0234 | Eval Loss: 0.2290 | Eval R2: -4.7620 |
# Epoch 8/30 | Train Loss: 0.0227 | Eval Loss: 0.2276 | Eval R2: -4.7286 |
# Epoch 9/30 | Train Loss: 0.0222 | Eval Loss: 0.2275 | Eval R2: -4.7251 |
# Epoch 10/30 | Train Loss: 0.0219 | Eval Loss: 0.2264 | Eval R2: -4.6982 |
# Epoch 11/30 | Train Loss: 0.0213 | Eval Loss: 0.2270 | Eval R2: -4.7118 |
# Epoch 12/30 | Train Loss: 0.0210 | Eval Loss: 0.2253 | Eval R2: -4.6716 |
# Epoch 13/30 | Train Loss: 0.0205 | Eval Loss: 0.2253 | Eval R2: -4.6749 |
# Epoch 14/30 | Train Loss: 0.0202 | Eval Loss: 0.2269 | Eval R2: -4.7107 |
# Epoch 15/30 | Train Loss: 0.0211 | Eval Loss: 0.2269 | Eval R2: -4.7124 |
# Epoch 16/30 | Train Loss: 0.0198 | Eval Loss: 0.2282 | Eval R2: -4.7420 |
# Epoch 17/30 | Train Loss: 0.0196 | Eval Loss: 0.2292 | Eval R2: -4.7699 |
# Epoch 18/30 | Train Loss: 0.0198 | Eval Loss: 0.2312 | Eval R2: -4.8145 |
# Epoch 19/30 | Train Loss: 0.0193 | Eval Loss: 0.2300 | Eval R2: -4.7847 |
# Epoch 20/30 | Train Loss: 0.0209 | Eval Loss: 0.2320 | Eval R2: -4.8365 |
# Epoch 21/30 | Train Loss: 0.0189 | Eval Loss: 0.2356 | Eval R2: -4.9196 |
# Epoch 22/30 | Train Loss: 0.0190 | Eval Loss: 0.2365 | Eval R2: -4.9401 |
# Epoch 23/30 | Train Loss: 0.0185 | Eval Loss: 0.2347 | Eval R2: -4.9001 |
# Epoch 24/30 | Train Loss: 0.0179 | Eval Loss: 0.2369 | Eval R2: -4.9510 |
# Epoch 25/30 | Train Loss: 0.0176 | Eval Loss: 0.2349 | Eval R2: -4.9046 |
# Epoch 26/30 | Train Loss: 0.0190 | Eval Loss: 0.2335 | Eval R2: -4.8714 |
# Epoch 27/30 | Train Loss: 0.0180 | Eval Loss: 0.2347 | Eval R2: -4.9008 |
# Epoch 28/30 | Train Loss: 0.0184 | Eval Loss: 0.2348 | Eval R2: -4.9017 |
# Epoch 29/30 | Train Loss: 0.0186 | Eval Loss: 0.2356 | Eval R2: -4.9213 |
# Epoch 30/30 | Train Loss: 0.0170 | Eval Loss: 0.2380 | Eval R2: -4.9799 |
# Entrenamiento completado.

# %%
plot_training_and_eval_losses(np.array(losses_brf), np.array(eval_losses_brf), 30, format_plot)

# %%
r2score_tst_brf, losses_tst_brf, loss_nodes_brf, predictions_brf, real_brf = train_lstm.test(model_brf, dataloader_brf)
# Out:
# ==================== TEST INFO ===================
#
# Test_loss:0.0194, Test_r2:0.7026

# %%
plot_predictions(predictions_brf, real_brf, 20, 0, n_div_brf, problem)

# %%
resultados_brf = {
    "loss_test": np.mean(losses_tst_brf),
    "r2_test": np.mean(r2score_tst_brf),
    "loss_nodes" : np.mean(loss_nodes_brf, axis=0),
    "r2_eval_final": r2scores_eval_brf[-1],
    "loss_eval_final": eval_losses_brf[-1],
    "loss_final": losses_brf[-1]
}


guardar_resultados(model_brf, "LSTM", problem, resultados_mejor_modelo=resultados_brf, results_path = "./results",path_save_experiment=None, params=None)
# Out:
# ==================== GUARDANDO RESULTADOS ===================
#
#   Modelo Params Fichero_resultados_experimento  Loss_tst    R2_tst  \
# 0   LSTM   None                           None  0.019392  0.702621
#
#                                           Loss_nodes   R2_eval  Loss_eval  \
# 0  [0.006797421, 0.006853461, 0.011191307, 0.0215... -4.979866   0.237984
#
#    Loss_final
# 0     0.01703
#
# ==================== RESULTADOS GUARDADOS ===================

# %% [markdown]
# ### Branch trip

# %%
problem = "branch_trip"
dataset_brt, situations_brt = loader.get_dataset( target= 20, intro=100, step=20, one_ts_per_situation=False, start = 1, type=problem)
# Out:
# Number of situations:  549
# Number of timestamps:  800
# Number of situations of the selected type:  101

# %%
n_div_brt = loader.div

# %% [markdown]
# #### Sencilla

# %%
dataloader_params2 = {
            "batch_size": 5,
            "data_split_ratio": [0.7, 0.15, 0.15],
            "seed": 42,
            "keep_same": True,
            "use_batch":True
}

params_model = {
    "hidden_size": 50,
    "n_layers": 2
}

dataloader_brt= trainer.train_test_val_split(dataset_brt, 
                                          batch_size=dataloader_params2["batch_size"], 
                                          data_split_ratio=dataloader_params2["data_split_ratio"], 
                                          random_seed=dataloader_params2["seed"], 
                                          keep_same=dataloader_params2["keep_same"], 
                                          use_batch=dataloader_params2["use_batch"])

model_brt, losses_brt, eval_losses_brt, r2scores_eval_brt = train_lstm.train_lstm_model(dataset_brt, params_model, dataloader_brt, num_epochs=30, lr=0.001, problem=problem, save_model = False, path_save = "./results" )
# Out:
# ==================== DATASET INFO ===================
#
# Train dataset: 2385
# Validation dataset: 510
# Test dataset: 505
#
# ==================== DATALOADER INFO ===================
#
# DataLoader for train set:
# Number of batches: 477
# DataLoader for val set:
# Number of batches: 102
# DataLoader for test set:
# Number of batches: 101
#
# ==================== TRAIN ===================
#
# Epoch 1/30 | Train Loss: 0.0582 | Eval Loss: 0.0788 | Eval R2: -20.5350 |
# Epoch 2/30 | Train Loss: 0.0084 | Eval Loss: 0.0942 | Eval R2: -26.6101 |
# Epoch 3/30 | Train Loss: 0.0071 | Eval Loss: 0.0962 | Eval R2: -27.4592 |
# Epoch 4/30 | Train Loss: 0.0064 | Eval Loss: 0.0989 | Eval R2: -28.5204 |
# Epoch 5/30 | Train Loss: 0.0058 | Eval Loss: 0.0988 | Eval R2: -28.4944 |
# Epoch 6/30 | Train Loss: 0.0053 | Eval Loss: 0.1011 | Eval R2: -29.4026 |
# Epoch 7/30 | Train Loss: 0.0049 | Eval Loss: 0.1025 | Eval R2: -29.9387 |
# Epoch 8/30 | Train Loss: 0.0045 | Eval Loss: 0.1033 | Eval R2: -30.2900 |
# Epoch 9/30 | Train Loss: 0.0043 | Eval Loss: 0.1010 | Eval R2: -29.3889 |
# Epoch 10/30 | Train Loss: 0.0041 | Eval Loss: 0.0993 | Eval R2: -28.7457 |
# Epoch 11/30 | Train Loss: 0.0039 | Eval Loss: 0.0953 | Eval R2: -27.1854 |
# Epoch 12/30 | Train Loss: 0.0037 | Eval Loss: 0.0951 | Eval R2: -27.1490 |
# Epoch 13/30 | Train Loss: 0.0036 | Eval Loss: 0.0950 | Eval R2: -27.1255 |
# Epoch 14/30 | Train Loss: 0.0035 | Eval Loss: 0.0949 | Eval R2: -27.0885 |
# Epoch 15/30 | Train Loss: 0.0035 | Eval Loss: 0.0939 | Eval R2: -26.6901 |
# Epoch 16/30 | Train Loss: 0.0034 | Eval Loss: 0.0962 | Eval R2: -27.5944 |
# Epoch 17/30 | Train Loss: 0.0034 | Eval Loss: 0.0992 | Eval R2: -28.7518 |
# Epoch 18/30 | Train Loss: 0.0033 | Eval Loss: 0.0987 | Eval R2: -28.5439 |
# Epoch 19/30 | Train Loss: 0.0033 | Eval Loss: 0.1013 | Eval R2: -29.5693 |
# Epoch 20/30 | Train Loss: 0.0032 | Eval Loss: 0.1035 | Eval R2: -30.3995 |
# Epoch 21/30 | Train Loss: 0.0032 | Eval Loss: 0.1051 | Eval R2: -31.0269 |
# Epoch 22/30 | Train Loss: 0.0032 | Eval Loss: 0.1066 | Eval R2: -31.6163 |
# Epoch 23/30 | Train Loss: 0.0031 | Eval Loss: 0.1071 | Eval R2: -31.8011 |
# Epoch 24/30 | Train Loss: 0.0031 | Eval Loss: 0.1075 | Eval R2: -31.9416 |
# Epoch 25/30 | Train Loss: 0.0031 | Eval Loss: 0.1079 | Eval R2: -32.1079 |
# Epoch 26/30 | Train Loss: 0.0030 | Eval Loss: 0.1077 | Eval R2: -32.0215 |
# Epoch 27/30 | Train Loss: 0.0030 | Eval Loss: 0.1081 | Eval R2: -32.1641 |
# Epoch 28/30 | Train Loss: 0.0030 | Eval Loss: 0.1066 | Eval R2: -31.5938 |
# Epoch 29/30 | Train Loss: 0.0029 | Eval Loss: 0.1054 | Eval R2: -31.1013 |
# Epoch 30/30 | Train Loss: 0.0029 | Eval Loss: 0.1052 | Eval R2: -31.0550 |
# Entrenamiento completado.

# %%
plot_training_and_eval_losses(np.array(losses_brt), np.array(eval_losses_brt), 30, format_plot)

# %%
r2score_tst_brt, losses_tst_brt, loss_nodes_brt, predictions_brt, real_brt = train_lstm.test(model_brt, dataloader_brt)
# Out:
# ==================== TEST INFO ===================
#
# Test_loss:0.0026, Test_r2:0.5833

# %%
plot_predictions(predictions_brt, real_brt, 20, 0, n_div_brt, problem)

# %%
resultados_brt = {
    "loss_test": np.mean(losses_tst_brt),
    "r2_test": np.mean(r2score_tst_brt),
    "loss_nodes" : np.mean(loss_nodes_brt, axis=0),
    "r2_eval_final": r2scores_eval_brt[-1],
    "loss_eval_final": eval_losses_brt[-1],
    "loss_final": losses_brt[-1]
}


guardar_resultados(model_brt, "LSTM", problem, resultados_mejor_modelo=resultados_brt, results_path = "./results",path_save_experiment=None, params=None)
# Out:
# ==================== GUARDANDO RESULTADOS ===================
#
#   Modelo Params Fichero_resultados_experimento  Loss_tst    R2_tst  \
# 0   LSTM   None                           None  0.002611  0.583308
#
#                                           Loss_nodes    R2_eval  Loss_eval  \
# 0  [0.002580365, 0.0012206553, 0.0016637268, 0.00... -31.054981   0.105248
#
#    Loss_final
# 0    0.002907
#
# ==================== RESULTADOS GUARDADOS ===================
